# %%
# Import package.
import pandas as pd

# Read CSV file from the current working directory.
fitness = pd.read_csv('daily_activity.csv')

fitness
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                1.88                      0.55
# 1                         0.0                1.57                      0.69
# 2                         0.0                2.44                      0.40
# 3                         0.0                2.14                      1.26
# 4                         0.0                2.71                      0.41
# ..                        ...                 ...                       ...
# 935                       0.0                1.08                      0.20
# 936                       0.0               11.10                      0.80
# 937                       0.0                1.35                      0.46
# 938                       0.0               13.22                      0.41
# 939                       0.0                1.82                      0.04
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   6.06                     0.00                 25
# 1                   4.71                     0.00                 21
# 2                   3.91                     0.00                 30
# 3                   2.83                     0.00                 29
# 4                   5.04                     0.00                 36
# ..                   ...                      ...                ...
# 935                 6.80                     0.00                 17
# 936                 6.24                     0.05                 73
# 937                 6.28                     0.00                 18
# 938                 5.89                     0.00                 88
# 939                 4.25                     0.00                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     13                   328               728      1985
# 1                     19                   217               776      1797
# 2                     11                   181              1218      1776
# 3                     34                   209               726      1745
# 4                     10                   221               773      1863
# ..                   ...                   ...               ...       ...
# 935                    4                   245              1174      2847
# 936                   19                   217              1131      3710
# 937                   11                   224              1187      2832
# 938                   12                   213              1127      3832
# 939                    1                   137               770      1849
#
# [940 rows x 15 columns]

# %%
my_list = fitness.columns.values.tolist()

print(my_list)
# Out:
# ['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance', 'LoggedActivitiesDistance', 'VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance', 'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']

# %%
my_list2 = list(fitness)

print(my_list2)
# Out:
# ['Id', 'ActivityDate', 'TotalSteps', 'TotalDistance', 'TrackerDistance', 'LoggedActivitiesDistance', 'VeryActiveDistance', 'ModeratelyActiveDistance', 'LightActiveDistance', 'SedentaryActiveDistance', 'VeryActiveMinutes', 'FairlyActiveMinutes', 'LightlyActiveMinutes', 'SedentaryMinutes', 'Calories']

# %%
# Selecting few columns.
fitness_fcol = pd.read_csv('daily_activity.csv', 
                            usecols=['Id', 'ActivityDate', 'TotalSteps'])

# Print the DataFrame.
fitness_fcol.head()
# Out:
#            Id ActivityDate  TotalSteps
# 0  1503960366    4/12/2016       13162
# 1  1503960366    4/13/2016       10735
# 2  1503960366    4/14/2016       10460
# 3  1503960366    4/15/2016        9762
# 4  1503960366    4/16/2016       12669

# %%
# Only return the first 10 rows.
fitness_nrows = pd.read_csv('daily_activity.csv', nrows=10)

# Print the DataFrame.
fitness_nrows
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
# 5  1503960366    4/17/2016        9705           6.48             6.48
# 6  1503960366    4/18/2016       13019           8.59             8.59
# 7  1503960366    4/19/2016       15506           9.88             9.88
# 8  1503960366    4/20/2016       10544           6.68             6.68
# 9  1503960366    4/21/2016        9819           6.34             6.34
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0                1.88                      0.55
# 1                         0                1.57                      0.69
# 2                         0                2.44                      0.40
# 3                         0                2.14                      1.26
# 4                         0                2.71                      0.41
# 5                         0                3.19                      0.78
# 6                         0                3.25                      0.64
# 7                         0                3.53                      1.32
# 8                         0                1.96                      0.48
# 9                         0                1.34                      0.35
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                        0                 25
# 1                 4.71                        0                 21
# 2                 3.91                        0                 30
# 3                 2.83                        0                 29
# 4                 5.04                        0                 36
# 5                 2.51                        0                 38
# 6                 4.71                        0                 42
# 7                 5.03                        0                 50
# 8                 4.24                        0                 28
# 9                 4.65                        0                 19
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863
# 5                   20                   164               539      1728
# 6                   16                   233              1149      1921
# 7                   31                   264               775      2035
# 8                   12                   205               818      1786
# 9                    8                   211               838      1775

# %%
# Shape of data frame.
print(fitness.shape)
# Out:
# (940, 15)

# %%
# Skiprows parameter.
fitness_skiprows = pd.read_csv('daily_activity.csv', skiprows=500)

# Print the DataFrame.
print(fitness_skiprows.shape)
# Out:
# (440, 15)

# %%
# Skiprows parameter.
fitness_skiprows = pd.read_csv('daily_activity.csv', skiprows=890)

# Print the DataFrame.
print(fitness_skiprows.shape)
# Out:
# (50, 15)

# %%
# Create a table indicating the total number of steps, total distance, and calories for all participants.
fitness_steps = pd.read_csv('daily_activity.csv', 
                            usecols=['TotalSteps','TotalDistance','Calories'])

# Print the DataFrame.
fitness_steps.head()
# Out:
#    TotalSteps  TotalDistance  Calories
# 0       13162           8.50      1985
# 1       10735           6.97      1797
# 2       10460           6.74      1776
# 3        9762           6.28      1745
# 4       12669           8.16      1863

# %%
# 2. Create a table to compare the four types of activity stages in terms of distance and minutes.
q2 = pd.read_csv ('daily_activity.csv',  
                  usecols=['Id', 
                           'VeryActiveDistance', 
                           'ModeratelyActiveDistance',
                           'LightActiveDistance', 
                           'SedentaryActiveDistance',
                           'VeryActiveMinutes',
                           'FairlyActiveMinutes',
                           'LightlyActiveMinutes', 
                           'SedentaryMinutes'])
q2.head()
# Out:
#            Id  VeryActiveDistance  ModeratelyActiveDistance  \
# 0  1503960366                1.88                      0.55
# 1  1503960366                1.57                      0.69
# 2  1503960366                2.44                      0.40
# 3  1503960366                2.14                      1.26
# 4  1503960366                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes
# 0                   13                   328               728
# 1                   19                   217               776
# 2                   11                   181              1218
# 3                   34                   209               726
# 4                   10                   221               773

# %%
q3 = pd.read_csv ('daily_activity.csv', 
                  nrows=15,  
                  usecols=['Id',
                           'Calories'])

q3
# Out:
#             Id  Calories
# 0   1503960366      1985
# 1   1503960366      1797
# 2   1503960366      1776
# 3   1503960366      1745
# 4   1503960366      1863
# 5   1503960366      1728
# 6   1503960366      1921
# 7   1503960366      2035
# 8   1503960366      1786
# 9   1503960366      1775
# 10  1503960366      1827
# 11  1503960366      1949
# 12  1503960366      1788
# 13  1503960366      2013
# 14  1503960366      1970

# %%
my_list = fitness.columns.values.tolist()

my_list
# Out:
# ['Id',
#  'ActivityDate',
#  'TotalSteps',
#  'TotalDistance',
#  'TrackerDistance',
#  'LoggedActivitiesDistance',
#  'VeryActiveDistance',
#  'ModeratelyActiveDistance',
#  'LightActiveDistance',
#  'SedentaryActiveDistance',
#  'VeryActiveMinutes',
#  'FairlyActiveMinutes',
#  'LightlyActiveMinutes',
#  'SedentaryMinutes',
#  'Calories']

# %%
(fitness['Calories'].sort_values())
# Out:
# 30        0
# 879       0
# 817       0
# 653       0
# 345      52
#        ...
# 585    4501
# 586    4546
# 913    4547
# 572    4552
# 606    4900
# Name: Calories, Length: 940, dtype: int64

# %%
# Add column cal_cat to calculate the middle number of calories.
fitness['cal_cat'] = fitness['Calories'] - fitness['Calories'].mean()

# Sense-check values of cal_cat column.
print(fitness['cal_cat'])

# Print to sense-check column was added.
fitness.head()
# Out:
# 0      -318.609574
# 1      -506.609574
# 2      -527.609574
# 3      -558.609574
# 4      -440.609574
#           ...
# 935     543.390426
# 936    1406.390426
# 937     528.390426
# 938    1528.390426
# 939    -454.609574
# Name: cal_cat, Length: 940, dtype: float64
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 6.06                      0.0                 25
# 1                 4.71                      0.0                 21
# 2                 3.91                      0.0                 30
# 3                 2.83                      0.0                 29
# 4                 5.04                      0.0                 36
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                   13                   328               728      1985
# 1                   19                   217               776      1797
# 2                   11                   181              1218      1776
# 3                   34                   209               726      1745
# 4                   10                   221               773      1863
#
#       cal_cat
# 0 -318.609574
# 1 -506.609574
# 2 -527.609574
# 3 -558.609574
# 4 -440.609574

# %%
# How many individuals per calory group.
fitness['cal_cat'].value_counts()
# Out:
# -323.609574     13
# -240.609574     11
# -615.609574      9
# -462.609574      9
# -956.609574      8
#                 ..
# -103.609574      1
#  1262.390426     1
#  1209.390426     1
#  230.390426      1
# -410.609574      1
# Name: cal_cat, Length: 734, dtype: int64
